# %% [markdown]
# # connect to google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # import packages

# %%
import os

import pandas as pd

# %%
# os.listdir('/content/drive/Shareddrives/數位醫學/case 1')
os.chdir('/content/drive/Shareddrives/數位醫學/case 1')
# print(os.getcwd())
# os.listdir()

# %% [markdown]
# # sample data

# %%
data_path = 'Case Presentation 1 Data'
data = {dataset:{name:open(os.path.join(data_path,dataset,name)).read() for name in os.listdir(os.path.join(data_path,dataset))} for dataset in os.listdir(data_path)}

# %%
print(data.keys())
# Out:
# dict_keys(['Test_Intuitive', 'Validation', 'Train_Textual'])

# %%
data['Train_Textual'].keys()
# Out:
# dict_keys(['U_ID_71.txt', 'Y_ID_134.txt', 'U_ID_69.txt', 'U_ID_59.txt', 'U_ID_151.txt', 'Y_ID_166.txt', 'U_ID_93.txt', 'U_ID_76.txt', 'U_ID_89.txt', 'U_ID_113.txt', 'Y_ID_65.txt', 'Y_ID_50.txt', 'U_ID_95.txt', 'Y_ID_147.txt', 'Y_ID_98.txt', 'Y_ID_104.txt', 'Y_ID_21.txt', 'U_ID_35.txt', 'U_ID_154.txt', 'Y_ID_128.txt', 'U_ID_2.txt', 'Y_ID_138.txt', 'U_ID_126.txt', 'U_ID_22.txt', 'U_ID_91.txt', 'U_ID_150.txt', 'Y_ID_51.txt', 'Y_ID_108.txt', 'Y_ID_132.txt', 'U_ID_75.txt', 'Y_ID_163.txt', 'Y_ID_84.txt', 'U_ID_81.txt', 'U_ID_155.txt', 'Y_ID_109.txt', 'U_ID_15.txt', 'Y_ID_78.txt', 'Y_ID_6.txt', 'Y_ID_13.txt', 'Y_ID_160.txt', 'U_ID_145.txt', 'Y_ID_133.txt', 'U_ID_19.txt', 'U_ID_47.txt', 'Y_ID_164.txt', 'U_ID_107.txt', 'Y_ID_70.txt', 'U_ID_127.txt', 'U_ID_4.txt', 'Y_ID_121.txt', 'U_ID_24.txt', 'Y_ID_130.txt', 'Y_ID_161.txt', 'U_ID_159.txt', 'U_ID_55.txt', 'Y_ID_20.txt', 'Y_ID_120.txt', 'U_ID_45.txt', 'U_ID_86.txt', 'Y_ID_62.txt', 'U_ID_77.txt', 'U_ID_135.txt', 'U_ID_61.txt', 'Y_ID_56.txt', 'U_ID_137.txt', 'Y_ID_68.txt', 'Y_ID_28.txt', 'Y_ID_114.txt', 'Y_ID_97.txt', 'U_ID_74.txt', 'U_ID_79.txt', 'U_ID_106.txt', 'Y_ID_85.txt', 'U_ID_64.txt', 'U_ID_36.txt', 'U_ID_26.txt', 'U_ID_27.txt', 'U_ID_704.txt', 'U_ID_303.txt', 'U_ID_281.txt', 'U_ID_477.txt', 'U_ID_733.txt', 'Y_ID_536.txt', 'U_ID_863.txt', 'U_ID_865.txt', 'U_ID_716.txt', 'Y_ID_301.txt', 'Y_ID_1054.txt', 'Y_ID_1028.txt', 'U_ID_664.txt', 'U_ID_730.txt', 'Y_ID_996.txt', 'U_ID_851.txt', 'U_ID_423.txt', 'Y_ID_246.txt', 'Y_ID_360.txt', 'U_ID_671.txt', 'Y_ID_316.txt', 'U_ID_270.txt', 'Y_ID_980.txt', 'U_ID_457.txt', 'U_ID_719.txt', 'Y_ID_524.txt', 'Y_ID_724.txt', 'U_ID_258.txt', 'Y_ID_985.txt', 'Y_ID_873.txt', 'U_ID_486.txt', 'U_ID_299.txt', 'U_ID_852.txt', 'Y_ID_489.txt', 'Y_ID_883.txt', 'U_ID_550.txt', 'Y_ID_916.txt', 'U_ID_508.txt', 'U_ID_702.txt', 'Y_ID_376.txt', 'Y_ID_186.txt', 'Y_ID_493.txt', 'U_ID_670.txt', 'U_ID_742.txt', 'Y_ID_674.txt', 'Y_ID_390.txt', 'U_ID_450.txt', 'Y_ID_971.txt', 'U_ID_342.txt', 'Y_ID_860.txt', 'U_ID_215.txt', 'Y_ID_930.txt', 'U_ID_194.txt', 'Y_ID_175.txt', 'Y_ID_529.txt', 'U_ID_337.txt', 'U_ID_657.txt', 'Y_ID_746.txt', 'Y_ID_335.txt', 'Y_ID_1007.txt', 'U_ID_464.txt', 'Y_ID_228.txt', 'Y_ID_955.txt', 'U_ID_686.txt', 'Y_ID_960.txt', 'Y_ID_1076.txt', 'Y_ID_522.txt', 'U_ID_410.txt', 'U_ID_463.txt', 'U_ID_878.txt', 'Y_ID_189.txt', 'Y_ID_199.txt', 'U_ID_237.txt', 'U_ID_498.txt', 'Y_ID_1027.txt', 'U_ID_422.txt', 'Y_ID_417.txt', 'Y_ID_680.txt', 'U_ID_182.txt', 'Y_ID_964.txt', 'U_ID_731.txt', 'U_ID_497.txt', 'U_ID_867.txt', 'U_ID_882.txt', 'U_ID_706.txt', 'Y_ID_932.txt', 'U_ID_701.txt', 'Y_ID_1021.txt', 'Y_ID_1012.txt', 'Y_ID_722.txt', 'Y_ID_1079.txt', 'U_ID_725.txt', 'Y_ID_976.txt', 'U_ID_267.txt', 'Y_ID_1051.txt', 'Y_ID_533.txt', 'U_ID_332.txt', 'Y_ID_941.txt', 'Y_ID_1043.txt', 'U_ID_446.txt', 'Y_ID_1080.txt', 'Y_ID_184.txt', 'Y_ID_400.txt', 'U_ID_465.txt', 'U_ID_260.txt', 'U_ID_891.txt', 'Y_ID_1069.txt', 'U_ID_747.txt', 'Y_ID_444.txt', 'Y_ID_466.txt', 'U_ID_506.txt', 'Y_ID_1072.txt', 'Y_ID_693.txt', 'U_ID_224.txt', 'Y_ID_918.txt', 'Y_ID_484.txt', 'U_ID_871.txt', 'U_ID_651.txt', 'Y_ID_494.txt', 'Y_ID_1067.txt', 'U_ID_744.txt', 'Y_ID_433.txt', 'Y_ID_673.txt', 'U_ID_348.txt', 'U_ID_255.txt', 'Y_ID_943.txt', 'Y_ID_430.txt', 'Y_ID_1016.txt', 'U_ID_413.txt', 'Y_ID_340.txt', 'U_ID_170.txt', 'Y_ID_1019.txt', 'U_ID_505.txt', 'Y_ID_1031.txt', 'Y_ID_935.txt', 'Y_ID_890.txt', 'U_ID_328.txt', 'U_ID_709.txt', 'Y_ID_1063.txt', 'Y_ID_991.txt', 'Y_ID_196.txt', 'U_ID_319.txt', 'U_ID_473.txt', 'Y_ID_984.txt', 'U_ID_507.txt', 'U_ID_394.txt', 'Y_ID_377.txt', 'U_ID_874.txt', 'U_ID_263.txt', 'U_ID_225.txt', 'Y_ID_881.txt', 'Y_ID_1050.txt', 'Y_ID_892.txt', 'U_ID_677.txt', 'U_ID_713.txt', 'Y_ID_715.txt', 'U_ID_291.txt', 'U_ID_737.txt', 'Y_ID_854.txt', 'U_ID_519.txt', 'Y_ID_857.txt', 'Y_ID_1037.txt', 'Y_ID_1052.txt', 'Y_ID_329.txt', 'U_ID_711.txt', 'U_ID_391.txt', 'Y_ID_945.txt', 'U_ID_278.txt', 'U_ID_381.txt', 'U_ID_872.txt', 'Y_ID_331.txt', 'Y_ID_665.txt', 'Y_ID_312.txt', 'Y_ID_897.txt', ' ...

# %%
data['Train_Textual']['Y_ID_147.txt']
# Out:
# "\n546299534 | CRH | 54433044 | | 6629491 | 2/5/2003 12:00:00 AM | supraspinatus tendonitis | | DIS | Admission Date: 6/11/2003 Report Status:\n\nDischarge Date: 4/17/2003\n****** DISCHARGE ORDERS ******\nDIVERS , EMORY O 084-86-53-0\nLisson Co Wa\nService: MED\nDISCHARGE PATIENT ON: 3/25/03 AT 12:00 M\nCONTINGENT UPON Not Applicable\nWILL D/C ORDER BE USED AS THE D/C SUMMARY: YES\nAttending: MARTELL , MAYNARD CALEB , M.D.\nCODE STATUS:\nFull code\nDISPOSITION: Home w/ services\nDISCHARGE MEDICATIONS:\nECASA ( ASPIRIN ENTERIC COATED ) 81 MG PO QD\nAlert overridden: Override added on 3/25/03 by\nCURENTON , FAUSTO JOSH , M.D.\nPOTENTIALLY SERIOUS INTERACTION: WARFARIN & ASPIRIN\nReason for override: will follow\nLASIX ( FUROSEMIDE ) 80 MG PO BID\nLOPRESSOR ( METOPROLOL TARTRATE ) 100 MG PO TID\nFood/Drug Interaction Instruction\nTake consistently with meals or on empty stomach.\nCOUMADIN ( WARFARIN SODIUM ) 4 MG PO QD\nFood/Drug Interaction Instruction\nNo high Vitamin-K containing foods\nOverride Notice: Override added on 3/25/03 by\nRONSANI , WILBERT MARK , M.D.\non order for ECASA PO ( ref # 98575658 )\nPOTENTIALLY SERIOUS INTERACTION: WARFARIN & ASPIRIN\nReason for override: will follow\nVICODIN ( HYDROCODONE 5 MG + APAP ) 2 TAB PO QAM\nAlert overridden: Override added on 3/25/03 by\nMADRIZ , RAMIRO GRAHAM , M.D.\nDEFINITE ALLERGY ( OR SENSITIVITY ) to NARCOTICS ,\nPHENANTHRENES Reason for override:\npt takes this as an outpatient\nVICODIN ( HYDROCODONE 5 MG + APAP ) 1 TAB PO QPM\nAlert overridden: Override added on 3/25/03 by\nCURIEL , DAVE IRVING , M.D.\nDEFINITE ALLERGY ( OR SENSITIVITY ) to NARCOTICS ,\nPHENANTHRENES Reason for override: pt takes\nK-DUR ( KCL SLOW RELEASE ) 20 MEQ X 1 PO BID\nAs per FMH Potassium Chloride Policy:\neach 20 mEq dose to be given with 4 oz of fluid\nCOZAAR ( LOSARTAN ) 50 MG PO QD\nNumber of Doses Required ( approximate ): 2\nNEXIUM ( ESOMEPRAZOLE ) 20 MG PO QD\nINDOCIN ( INDOMETHACIN ) 25 MG PO BID\nInstructions: please take twice a day ( as directed by Dr.\nJonassen ) until your follow-up appointment on Friday\nFood/Drug Interaction Instruction Take with food\nAlert overridden: Override added on 3/25/03 by :\nPOTENTIALLY SERIOUS INTERACTION: LOSARTAN POTASSIUM &\nINDOMETHACIN Reason for override: monitoring\nDIET: Fluid restriction: 2 liters\nDIET: House / Low chol/low sat. fat\nDIET: 2 gram Sodium\nACTIVITY: Resume regular exercise\nFOLLOW UP APPOINTMENT( S ):\nDr. Ballantine , Friday , 6/3/03 , 11:15 am ,\nArrange INR to be drawn on 1/19/03 with f/u INR's to be drawn every\n30 days. INR's will be followed by NOCKER JCORN WAWEST HOSPITAL coumadin clinic\nALLERGY: pentothal , Codeine , Iv contrast dyes , Methyldopa ,\nAmitriptyline hcl\nADMIT DIAGNOSIS:\nshoulder pain\nPRINCIPAL DISCHARGE DIAGNOSIS ;Responsible After Study for Causing Admission )\nsupraspinatus tendonitis\nOTHER DIAGNOSIS;Conditions , Infections , Complications , affecting Treatment/Stay\nHTN OBESITY\nUTI , ON BACTRIM arthritis ( arthritis ) s/p bil TKR ( S/P total knee\nreplacement ) CHF? ( congestive heart failure )\nOPERATIONS AND PROCEDURES:\nOTHER TREATMENTS/PROCEDURES ( NOT IN O.R. )\nNone\nBRIEF RESUME OF HOSPITAL COURSE:\n76 year old woman with CHF , moderate MR , PAF , HTN , and obesity who\npresented with left upper arm pain since 3 pm the day of admission.\nDenies any SOB , CP , N/V , diaphroresis. Took 5 baby aspirin at\nhome without relief of pain. Pain came on at rest. No history of\nrecent trauma. In ED , MSO4 relieved most of pain. Pain was noted to be\npositional , increasing when arm is stretched down. Reports\nincreasing SOB over last several months , increased leg edema with 10\nlb weight gain. No orthopnea or PND. PE: HR 58-61 , BP 141/81 98% RA.\nPE: tenderness to palpation over L deltoid with pain with resistance to\nabduction ( +supraspinatus involvement ). Full ROM in bilateral\nshoulders. Chest: CTA bil. Neck: JVP 7 cm. ECG: 1st degree AVB , no\nischemic changes. CXR: no acute cardiopulmonary chan ...

# %% [markdown]
# ## text preprocssing

# %%
import re
for key, value in data['Train_Textual'].items():
  value = re.sub(r'[\n|*:,.()]' ,' ',value.lower())
  # value = value.split(' ')
  data['Train_Textual'][key] = value

for key, value in data['Test_Intuitive'].items():
  value = re.sub(r'[\n|*:,.()]' ,' ',value.lower())
  # value = value.split(' ')
  data['Test_Intuitive'][key] = value

for key, value in data['Validation'].items():
  value = re.sub(r'[\n|*:,.()]' ,' ',value.lower())
  # value = value.split(' ')
  data['Validation'][key] = value

# %%
data['Train_Textual']['Y_ID_97.txt']
# Out:
# " 331541352   d   63185945     6072765   10/20/2005 12 00 00 am   intra abdominal abscess   signed   dis   admission date  8/8/2005 report status  signed  discharge date  5/29/2005 attending  esteban trachte md attending physician  byron finnin   m d  admitting diagnosis  intraabdominal abscess  history of present illness  the patient is a 77-year-old female with history of hypertension and perforated sigmoid diverticulitis status post a partial colectomy at the splenic flexure and hartmann pouch on 2/28/05   who presented at an outside hospital with chills and fevers of temperature of 103 degrees fahrenheit   as well as shortness of breath and hypotension  the patient was transferred to the shire hospital for further care  she denied nausea   vomiting   and had only mild abdominal pain and abdominal distension noted per the patient  however   her fevers and chills continued  past medical history  hypertension   chronic back pain   and nephrolithiasis  past surgical history  right total knee replacement   appendectomy   cholecystectomy   and partial colectomy at the splenic flexure as noted above  medications  lopressor 50 mg p o  t i d    lisinopril 15 mg p o  q d    lasix 40 mg p o  q d    aspirin 81 mg p o  q d    albuterol nebulizer p r n    zyprexa 2 5 mg p o  q d    ms contin 15 mg to 30 mg p o  b i d    oxycodone as needed   and heparin subcutaneous t i d  allergies  no known drug allergies  social history  the patient presented after a brief stay for one week at councoovir catbelle medical center of    she is the aunt of a pageway hospital cardiologist   dr  cavalli   physical examination  temperature is 98 8   heart rate 94   blood pressure 80/54   respiratory rate 18   and oxygen saturation 95% on 2 liters nasal cannula  in general   the patient was in no acute distress  her chest was clear to auscultation bilaterally without any evidence of wheezes  the heart was regular rate and rhythm with s1   s2 normal with 3/6 systolic murmur  abdomen was soft and obese  mild tenderness of the inferior aspect of her ostomy stoma  no rebound tenderness was noted  the stoma color was normal  there was gas and stool in the stoma bag  her midline abdominal incision was open with pink granulation tissue  extremities were notable for only trace pitting edema  laboratory data  chemistry  sodium 139   potassium 5 0   chloride 100   bicarbonate 34   bun 25   creatinine 0 8   and glucose 187  liver enzymes  ast 8   alt 13   alkaline phosphatase 89   and t-bili 0 2   and lactic acid 1 2  cbc  white blood cell count 13 5   hematocrit 31 3   and platelets 513   000  cardiac enzymes were normal with the ck of 33 and mb fraction of 1 2  troponin was less than assay  ekg showed left anterior fascicular block and sinus rhythm  imaging  ct of the abdomen showed a 6 cm x 2 cm left-sided intraabdominal fluid collection and a 4 2 cm fluid collection around the stoma   which both were seemed to as consistent with abscess formation  hospital course  the patient was admitted to the windreal claall onli medical center surgical service on 1/12/05 for management of her intraabdominal abscesses as a complication of recently performed partial colectomy and hartmann pouch for perforated diverticulitis  she was started on iv antibiotics with vancomycin   levofloxacin   and flagyl  by systems  neuro  the patient had intermittent issues with pain control   which were managed by putting the patient on oral narcotic agents as well as fentanyl patch  this seemed to help the patient's pain  the patient also had an episode of altered mental status   which was believed to be due to pulmonary issues of co2 retention as noted below  for this reason   the patient had been transferred to the icu for 24-hour period observation   and at the time of discharge   the patient was in adequate mental status communicating effectively and at her baseline  otherwise   no issues at the time of discharge   except for pain control   being managed by narcotic agents  cardiovascular  t ...

# %% [markdown]
# # keyword

# %%
keyword_path = 'keyword'
os.listdir(keyword_path)
# Out:
# ['Term_147_0.xlsx',
#  'Term_150_0.xlsx',
#  'Term_Recognizing Obesity and Comorbidities in Sparse Data.gsheet',
#  'Term_Refers.xls',
#  'hahou']

# %%
df_keyword = pd.DataFrame()
for i in os.listdir(keyword_path):
  if 'xlsx' in i:
    df_keyword = df_keyword.append(pd.read_excel(os.path.join(keyword_path,i))[["英文名稱","中文名稱"]])
  elif 'xls' in i:
    df_tmp = pd.read_excel(os.path.join(keyword_path,i))[["keywords","中文"]]
    df_keyword = df_keyword.append(df_tmp.rename(columns={"keywords":"英文名稱","中文":"中文名稱"}))
  else:
    print(i)

set_keyword = set(df_keyword['英文名稱'].apply(lambda x:x.lower()))
# Out:
# Term_Recognizing Obesity and Comorbidities in Sparse Data.gsheet
# hahou

# %%
temp = set()
for item in set_keyword:
  if ';' in item:
    print(item) if '17' in item else 0
    # {y for x in item.split(';') for y in x.split(' ')}
    # temp = temp.union({y for x in item.split(';') for y in x.split(' ')})
    temp = temp.union({x.strip() for x in item.split(';')})
    # set_keyword.remove(item)
# Out:
# brownism (brown1735-88); brunonianism; brunonian theory
# 17;20-desmolase deficiency

# %%
set_keyword = set_keyword.union(temp)

# %%
# set_keyword.remove(False)

# %%
# set_keyword

# %% [markdown]
# # obese

# %% [markdown]
# ## Mention obese or not
# Using crosstable check

# %%
obesity = {'obese', 'obesity', 'overweight', 
          #  'fat'
}

# %%
def fun_keycount(df:pd.DataFrame,dict_input :dict, keywords:set):
  df
  for key, value in dict_input.items():
    for keyword in keywords: 
      df.loc[key, keyword] = value.count(f' {keyword} ')
    
  return df

# %%
df_obese_mention = pd.DataFrame()
for key,value in data['Train_Textual'].items():
  df_obese_mention.loc[key,'file_type'] = True if key[0] == 'Y' else False
  df_obese_mention.loc[key,'obesity mentioned'] = sum([i.lower() in value for i in obesity]) > 0
  for keyword in obesity:
    df_obese_mention.loc[key, keyword] = value.count(f' {keyword} ')
    # df_obese_mention.loc[key, keyword] = 1 if keyword in value else 0
df_obese_mention
# Out:
#              file_type obesity mentioned  obese  obesity  overweight
# U_ID_71.txt      False             False    0.0      0.0         0.0
# Y_ID_134.txt      True              True    1.0      1.0         0.0
# U_ID_69.txt      False             False    0.0      0.0         0.0
# U_ID_59.txt      False             False    0.0      0.0         0.0
# U_ID_151.txt     False             False    0.0      0.0         0.0
# ...                ...               ...    ...      ...         ...
# Y_ID_968.txt      True             False    0.0      0.0         0.0
# U_ID_866.txt     False             False    0.0      0.0         0.0
# U_ID_274.txt     False             False    0.0      0.0         0.0
# U_ID_416.txt     False             False    0.0      0.0         0.0
# U_ID_398.txt     False             False    0.0      0.0         0.0
#
# [400 rows x 5 columns]

# %%
pd.crosstab(df_obese_mention['file_type'], df_obese_mention['obesity mentioned'], rownames=['file mentioned'], colnames=['obesity mentioned'])
# Out:
# obesity mentioned  False  True
# file mentioned
# False                185     15
# True                  56    144

# %%
df_test = pd.DataFrame()
for key,value in data['Test_Intuitive'].items():
  df_test.loc[key,'file_type'] = True if key[0] == 'Y' else False
  df_test.loc[key,'obesity mentioned'] = sum([i.lower() in value for i in obesity]) > 0
  for keyword in obesity:
    df_test.loc[key, keyword] = value.count(f' {keyword} ')
    # df_test.loc[key, keyword] = 1 if keyword in value else 0
df_test
# Out:
#              file_type obesity mentioned  obese  obesity  overweight
# N_ID_127.txt     False             False    0.0      0.0         0.0
# Y_ID_84.txt       True              True    1.0      3.0         0.0
# Y_ID_133.txt      True              True    2.0      2.0         0.0
# Y_ID_132.txt      True              True    1.0      3.0         0.0
# Y_ID_128.txt      True              True    1.0      0.0         0.0
# ...                ...               ...    ...      ...         ...
# Y_ID_320.txt      True              True    2.0      0.0         0.0
# Y_ID_861.txt      True              True    0.0      1.0         0.0
# Y_ID_936.txt      True              True    0.0      0.0         0.0
# N_ID_502.txt     False             False    0.0      0.0         0.0
# Y_ID_910.txt      True              True    0.0      1.0         0.0
#
# [400 rows x 5 columns]

# %%
pd.crosstab(df_test['file_type'], df_test['obesity mentioned'], rownames=['obesity'], colnames=['obesity mentioned'])
# Out:
# obesity mentioned  False  True
# obesity
# False                200      0
# True                   7    193

# %%
df_vaild = pd.DataFrame()
for key,value in data['Validation'].items():
  # df_vaild.loc[key,'file_type'] = True if key[0] == 'Y' else False
  df_vaild.loc[key,'obesity mentioned'] = sum([i.lower() in value for i in obesity]) > 0
  for keyword in obesity:
    df_vaild.loc[key, keyword] = value.count(f' {keyword} ')
    # df_vaild.loc[key, keyword] = 1 if keyword in value else 0
df_vaild
# Out:
#             obesity mentioned  obese  obesity  overweight
# ID_1201.txt             False    0.0      0.0         0.0
# ID_1213.txt             False    0.0      0.0         0.0
# ID_1198.txt             False    0.0      0.0         0.0
# ID_1229.txt              True    0.0      0.0         0.0
# ID_1162.txt              True    2.0      2.0         0.0
# ID_1167.txt             False    0.0      0.0         0.0
# ID_1222.txt              True    2.0      0.0         0.0
# ID_1210.txt             False    0.0      0.0         0.0
# ID_1212.txt             False    0.0      0.0         0.0
# ID_1187.txt              True    0.0      1.0         0.0
# ID_1194.txt              True    1.0      0.0         0.0
# ID_1235.txt             False    0.0      0.0         0.0
# ID_1186.txt             False    0.0      0.0         0.0
# ID_1214.txt             False    0.0      0.0         0.0
# ID_1202.txt             False    0.0      0.0         0.0
# ID_1240.txt             False    0.0      0.0         0.0
# ID_1234.txt             False    0.0      0.0         0.0
# ID_1220.txt              True    0.0      1.0         0.0
# ID_1185.txt              True    1.0      0.0         0.0
# ID_1233.txt             False    0.0      0.0         0.0
# ID_1226.txt              True    1.0      2.0         0.0
# ID_1219.txt              True    3.0      3.0         0.0
# ID_1243.txt              True    2.0      3.0         0.0
# ID_1183.txt             False    0.0      0.0         0.0
# ID_1159.txt             False    0.0      0.0         0.0
# ID_1223.txt             False    0.0      0.0         0.0
# ID_1217.txt             False    0.0      0.0         0.0
# ID_1200.txt             False    0.0      0.0         0.0
# ID_1203.txt             False    0.0      0.0         0.0
# ID_1168.txt             False    0.0      0.0         0.0
# ID_1236.txt              True    1.0      2.0         0.0
# ID_1197.txt              True    1.0      1.0         1.0
# ID_1208.txt              True    2.0      2.0         0.0
# ID_1242.txt             False    0.0      0.0         0.0
# ID_1189.txt             False    0.0      0.0         0.0
# ID_1237.txt             False    0.0      0.0         0.0
# ID_1238.txt             False    0.0      0.0         0.0
# ID_1209.txt              True    1.0      0.0         0.0
# ID_1232.txt             False    0.0      0.0         0.0
# ID_1205.txt             False    0.0      0.0         0.0
# ID_1180.txt             False    0.0      0.0         0.0
# ID_1176.txt             False    0.0      0.0         0.0
# ID_1184.txt             False    0.0      0.0         0.0
# ID_1216.txt             False    0.0      0.0         0.0
# ID_1191.txt             False    0.0      0.0         0.0
# ID_1193.txt              True    1.0      1.0         0.0
# ID_1190.txt             False    0.0      0.0         0.0
# ID_1211.txt             False    0.0      0.0         0.0
# ID_1160.txt              True    1.0      0.0         0.0
# ID_1239.txt              True    2.0      0.0         0.0

# %% [markdown]
# ## there is no keywords, such as 'obese' in these files.

# %%
dict_Y = {}
dict_U = {}
for key,value in data['Train_Textual'].items():
  if 'Y' in key:
    dict_Y[key] = value
  else:
    dict_U[key] = value

# %%
for key, value in dict_U.items():
  if sum([i.lower() in value for i in obesity]) != 0:
    print(key, sum([i.lower() in value for i in obesity]))
# Out:
# U_ID_716.txt 2
# U_ID_851.txt 1
# U_ID_882.txt 1
# U_ID_725.txt 1
# U_ID_891.txt 1
# U_ID_747.txt 2
# U_ID_874.txt 1
# U_ID_713.txt 1
# U_ID_737.txt 2
# U_ID_855.txt 2
# U_ID_861.txt 1
# U_ID_728.txt 1
# U_ID_877.txt 1
# U_ID_884.txt 1
# U_ID_740.txt 2

# %%
# [key if (sum([i.lower() in value for i in obesity]) == 0) for key, value in dict_Y.items()]
for key, value in dict_Y.items():
  if sum([i.lower() in value for i in obesity]) == 0:
    print(key, sum([i.lower() in value for i in obesity]))
# Out:
# Y_ID_21.txt 0
# Y_ID_6.txt 0
# Y_ID_20.txt 0
# Y_ID_1054.txt 0
# Y_ID_996.txt 0
# Y_ID_873.txt 0
# Y_ID_883.txt 0
# Y_ID_746.txt 0
# Y_ID_960.txt 0
# Y_ID_1076.txt 0
# Y_ID_1027.txt 0
# Y_ID_932.txt 0
# Y_ID_1012.txt 0
# Y_ID_722.txt 0
# Y_ID_1079.txt 0
# Y_ID_976.txt 0
# Y_ID_941.txt 0
# Y_ID_1043.txt 0
# Y_ID_1072.txt 0
# Y_ID_943.txt 0
# Y_ID_1031.txt 0
# Y_ID_935.txt 0
# Y_ID_890.txt 0
# Y_ID_1063.txt 0
# Y_ID_991.txt 0
# Y_ID_1050.txt 0
# Y_ID_892.txt 0
# Y_ID_715.txt 0
# Y_ID_854.txt 0
# Y_ID_857.txt 0
# Y_ID_1037.txt 0
# Y_ID_945.txt 0
# Y_ID_897.txt 0
# Y_ID_954.txt 0
# Y_ID_876.txt 0
# Y_ID_734.txt 0
# Y_ID_929.txt 0
# Y_ID_750.txt 0
# Y_ID_1065.txt 0
# Y_ID_1089.txt 0
# Y_ID_868.txt 0
# Y_ID_949.txt 0
# Y_ID_987.txt 0
# Y_ID_983.txt 0
# Y_ID_915.txt 0
# Y_ID_1047.txt 0
# Y_ID_739.txt 0
# Y_ID_880.txt 0
# Y_ID_1006.txt 0
# Y_ID_726.txt 0
# Y_ID_1002.txt 0
# Y_ID_909.txt 0
# Y_ID_978.txt 0
# Y_ID_904.txt 0
# Y_ID_921.txt 0
# Y_ID_968.txt 0

# %% [markdown]
# ## find other keywords
# other_key was mentioned in paper, *Recognizing Obesity and Comorbidities in Sparse Data*,  table 1.

# %%
other_key = {'Asthma','Atherosclerotic CV disease', 'CAD', 'Congestive heart failure', 'CHF','Depression',
      'Diabetes mellitus','Gallstones','cholecystectomy','GERD','Gout','Hypercholesterolemia',
      'Hypertension','HTN','Hypertriglyceridemia','Obstructive sleep apnea','OSA','Osteoarthritis','OA',
      'Peripheral vascular disease','PVD','Venous insufficiency',
      'fatty liver','edema','hypertension','cholesterol','diabetes mellitus','DM','Cardiology','hypercholesterolemia','lipidemia','hypothyroidism'
      }

# %% [markdown]
# ## analysis

# %%
assemble_list_Y = []
for value in dict_Y.values():
  assemble_list_Y += value


assemble_list_U = []
for value in dict_U.values():
  assemble_list_U += value

# %%
dict_out1 = {}
for value in dict_Y.values():
  for key in set_keyword:
    if f' {key} ' in value:
      dict_out1[key] = dict_out1.get(key, 0) + 1

for value in dict_U.values():
  for key in set_keyword:
    if f' {key} ' in value:
      dict_out1[key] = dict_out1.get(key, 0) + 1

# %%
dict_out2 = {}
for key, value in dict_out1.items():
  if (value < 250) and (value > 15):
    dict_out2[key] = value

# %%
dict_out2
# Out:
# {'17': 54,
#  'abscess': 21,
#  'agitation': 18,
#  'allergy': 167,
#  'anemia': 86,
#  'arthritis': 27,
#  'beta-blocker': 23,
#  'bilirubin': 22,
#  'biopsy': 24,
#  'blood pressure': 189,
#  'bradycardia': 31,
#  'breast': 23,
#  'burning': 19,
#  'bypass': 83,
#  'calcium': 84,
#  'cancer': 37,
#  'cardiology': 98,
#  'chf': 99,
#  'cholecystectomy ': 28,
#  'cholesterol': 77,
#  'cholesterol ': 43,
#  'complaint': 38,
#  'congestive heart failure ': 92,
#  'coronary artery disease': 155,
#  'ct': 100,
#  'defect': 27,
#  'deficiency': 28,
#  'depression': 76,
#  'depression ': 50,
#  'diabetes': 230,
#  'diabetes mellitus': 158,
#  'diabetes mellitus ': 138,
#  'diabetic': 49,
#  'diet ': 224,
#  'disorder': 29,
#  'dm': 90,
#  'dysfunction': 53,
#  'dyslipidemia': 16,
#  'edema': 237,
#  'effect': 22,
#  'endocrine': 70,
#  'etiology': 37,
#  'exercise': 114,
#  'factor': 17,
#  'fat': 117,
#  'female': 88,
#  'fracture': 19,
#  'function': 102,
#  'gallstones': 16,
#  'gastroesophageal reflux disease': 21,
#  'gerd ': 39,
#  'glucose': 101,
#  'gout': 49,
#  'gout ': 41,
#  'heart disease': 17,
#  'hematology': 27,
#  'htn': 135,
#  'hypercholesterolemia': 80,
#  'hypercholesterolemia ': 70,
#  'hyperlipidemia': 39,
#  'hypertension': 229,
#  'hypertension ': 210,
#  'hypertrophy': 43,
#  'hypotension': 28,
#  'hypothyroidism': 37,
#  'illness': 212,
#  'infection': 103,
#  'infectious disease': 50,
#  'insufficiency': 63,
#  'insulin': 174,
#  'iron deficiency': 20,
#  'kidney': 20,
#  'lesion': 53,
#  'levothyroxine': 31,
#  'lipase': 20,
#  'liver': 54,
#  'loss': 64,
#  'lung': 57,
#  'lymphadenopathy': 39,
#  'mri': 35,
#  'muscle': 23,
#  'neurology': 19,
#  'neuropathy': 30,
#  'nutrition': 38,
#  'obese': 116,
#  'obesity': 97,
#  'obesity ': 84,
#  'obstructive sleep apnea ': 18,
#  'osa': 27,
#  'osteoarthritis': 33,
#  'osteoarthritis ': 24,
#  'oxygen': 78,
#  'pancreatitis': 16,
#  'phosphatase': 22,
#  'platelet': 29,
#  'prostate': 19,
#  'pulmonary disease': 22,
#  'respiratory': 113,
#  'rhythm': 189,
#  'salt': 21,
#  'scar': 30,
#  'shock': 16,
#  'skin': 61,
#  'sleep': 74,
#  'stage': 20,
#  'stroke': 28,
#  'sugar': 42,
#  'sugars': 48,
#  'swelling': 66,
#  'syndrome': 58,
#  'system': 49,
#  'thyroid': 22,
#  'trauma': 26,
#  'urinary tract': 35,
#  'vascular disease': 48,
#  'vitamin': 40,
#  'wound': 60}

# %%
other_key = other_key.union(set_keyword.intersection(set(dict_out2.keys())))

# %%
df_obese_mention = fun_keycount(df_obese_mention, data['Train_Textual'], other_key)
df_obese_mention.head()
# Out:
#              file_type obesity mentioned  ...  illness  hyperlipidemia
# U_ID_71.txt      False             False  ...      0.0             0.0
# Y_ID_134.txt      True              True  ...      0.0             0.0
# U_ID_69.txt      False             False  ...      0.0             0.0
# U_ID_59.txt      False             False  ...      0.0             0.0
# U_ID_151.txt     False             False  ...      1.0             2.0
#
# [5 rows x 146 columns]

# %%
df_test = fun_keycount(df_test, data['Test_Intuitive'], other_key)
df_test.head()
# Out:
#              file_type obesity mentioned  ...  illness  hyperlipidemia
# N_ID_127.txt     False             False  ...      1.0             0.0
# Y_ID_84.txt       True              True  ...      0.0             0.0
# Y_ID_133.txt      True              True  ...      1.0             0.0
# Y_ID_132.txt      True              True  ...      0.0             0.0
# Y_ID_128.txt      True              True  ...      0.0             0.0
#
# [5 rows x 146 columns]

# %%
df_vaild = fun_keycount(df_vaild, data['Validation'], other_key)
df_vaild.head()
# Out:
#             obesity mentioned  obese  ...  illness  hyperlipidemia
# ID_1201.txt             False    0.0  ...      1.0             1.0
# ID_1213.txt             False    0.0  ...      1.0             0.0
# ID_1198.txt             False    0.0  ...      1.0             0.0
# ID_1229.txt              True    0.0  ...      1.0             0.0
# ID_1162.txt              True    2.0  ...      0.0             0.0
#
# [5 rows x 145 columns]

# %% [markdown]
# # model

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100000,max_depth=10)
model.fit(df_obese_mention.iloc[:,2:],df_obese_mention.iloc[:,0].apply(lambda x : 'True' if x else 'False'))
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=10, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100000,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# ## training dataset predict

# %%
model.score(df_obese_mention.iloc[:,2:],df_obese_mention.iloc[:,0].apply(lambda x : 'True' if x else 'False'))
# Out:
# 0.945

# %%
df_predict = df_obese_mention[['file_type','obesity mentioned']]
df_predict.loc[:,'predict'] = model.predict(df_obese_mention.iloc[:,2:])
df_predict
pd.crosstab(df_predict['file_type'], df_predict['predict'], rownames=['obesity'], colnames=['predict'])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# predict  False  True
# obesity
# False      200     0
# True        22   178

# %%
df_tmp = pd.crosstab(df_predict['file_type'], df_predict['predict'], rownames=['obesity'], colnames=['predict'])
df_score = pd.DataFrame()
df_score.loc['train','TP'] = df_tmp.iloc[1,1]/(df_tmp.iloc[1,1]+df_tmp.iloc[1,0])
df_score.loc['train','TN'] = df_tmp.iloc[0,0]/(df_tmp.iloc[0,1]+df_tmp.iloc[0,0])
df_score.loc['train','FP'] = df_tmp.iloc[1,0]/(df_tmp.iloc[1,1]+df_tmp.iloc[1,0])
df_score.loc['train','FN'] = df_tmp.iloc[0,1]/(df_tmp.iloc[0,1]+df_tmp.iloc[0,0])
df_score
# Out:
#          TP   TN    FP   FN
# train  0.89  1.0  0.11  0.0

# %% [markdown]
# ## testing dataset predict

# %%
model.score(df_test.iloc[:,2:],df_test.iloc[:,0].apply(lambda x : 'True' if x else 'False'))
# Out:
# 0.9275

# %%
df_predict = df_test.copy()
df_predict.loc[:,'predict'] = model.predict(df_test.iloc[:,2:])
df_predict
pd.crosstab(df_predict['file_type'], df_predict['predict'], rownames=['obesity'], colnames=['predict'])
# Out:
# predict  False  True
# obesity
# False      187    13
# True        16   184

# %%
df_tmp = pd.crosstab(df_predict['file_type'], df_predict['predict'], rownames=['obesity'], colnames=['predict'])
df_score.loc['test','TP'] = df_tmp.iloc[1,1]/(df_tmp.iloc[1,1]+df_tmp.iloc[1,0])
df_score.loc['test','TN'] = df_tmp.iloc[0,0]/(df_tmp.iloc[0,1]+df_tmp.iloc[0,0])
df_score.loc['test','FP'] = df_tmp.iloc[1,0]/(df_tmp.iloc[1,1]+df_tmp.iloc[1,0])
df_score.loc['test','FN'] = df_tmp.iloc[0,1]/(df_tmp.iloc[0,1]+df_tmp.iloc[0,0])
df_score
# Out:
#          TP     TN    FP     FN
# train  0.89  1.000  0.11  0.000
# test   0.92  0.935  0.08  0.065

# %% [markdown]
# ## validation dataset predict

# %%
df_ouput = df_vaild.copy()
df_ouput['Obesity'] = model.predict(df_vaild.iloc[:,1:])
df_ouput['Obesity'] = df_ouput['Obesity'].apply(lambda x : 1 if x == 'True' else 0)

# %%
df_ouput.index.name = 'Filename'

# %%
df_ouput['Obesity'].head()
# Out:
# Filename
# ID_1201.txt    0
# ID_1213.txt    0
# ID_1198.txt    0
# ID_1229.txt    0
# ID_1162.txt    1
# Name: Obesity, dtype: int64

# %%
df_ouput['Obesity'].to_csv('ouput_version3.csv')

# %%
df_ouput['Obesity'].sum()
# Out:
# 19

# %%
df_obese_mention.columns[2:]
# Out:
# Index(['obese', 'obesity', 'overweight', 'diet ', 'Congestive heart failure',
#        'Obstructive sleep apnea', 'osteoarthritis', 'lipidemia', 'burning',
#        'thyroid',
#        ...
#        'Asthma', 'insulin', 'obstructive sleep apnea ', 'gallstones',
#        'insufficiency', 'cholesterol', 'infection', 'diabetic', 'illness',
#        'hyperlipidemia'],
#       dtype='object', length=144)

# %%
df_feature = pd.DataFrame()
df_feature['keyword'] = df_obese_mention.columns[2:]
df_feature['feature importance'] = model.feature_importances_

# %%
df_feature.sort_values(by='feature importance', ascending=False).iloc[:40]
# Out:
#                       keyword  feature importance
# 0                       obese            0.172687
# 1                     obesity            0.091668
# 23                   obesity             0.073506
# 3                       diet             0.016948
# 106                     sleep            0.015617
# 135                   insulin            0.015057
# 25          pulmonary disease            0.012982
# 58                        htn            0.011907
# 119                       chf            0.011827
# 67                   diabetes            0.011585
# 95    coronary artery disease            0.011384
# 113                     edema            0.011184
# 17               hypertension            0.010549
# 52             blood pressure            0.010511
# 140                 infection            0.009981
# 68                        osa            0.009794
# 116                    rhythm            0.009537
# 10                     female            0.009337
# 117             hypertension             0.009147
# 66                         dm            0.009096
# 89                   exercise            0.008850
# 49          diabetes mellitus            0.008725
# 53                 cardiology            0.008524
# 33                    allergy            0.008487
# 32                     anemia            0.008373
# 50                  arthritis            0.008297
# 82                         ct            0.008283
# 59                respiratory            0.008163
# 88                   function            0.008087
# 75                       lung            0.008082
# 30                     lesion            0.007952
# 136  obstructive sleep apnea             0.007711
# 44                      wound            0.007581
# 94                     bypass            0.007478
# 28                 depression            0.007434
# 129                   glucose            0.007408
# 86                   syndrome            0.007050
# 85                     defect            0.006924
# 54                        mri            0.006651
# 11                      liver            0.006461
